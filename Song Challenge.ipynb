# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Preprocessing

# %%
song = pd.read_json('song.json')
song = song.set_index('id')
song.user_sign_up_date = pd.to_datetime(song.user_sign_up_date)
song.time_played = pd.to_datetime(song.time_played)
song.head()
# Out:
#             user_id  user_state user_sign_up_date  \
# id
# GOQMMKSQQH      122   Louisiana        2015-05-16
# HWKKBQKNWI        3        Ohio        2015-05-01
# DKQSXVNJDH       35  New Jersey        2015-05-04
# HLHRIDQTUW      126    Illinois        2015-05-16
# SUKJCSBCYW        6  New Jersey        2015-05-01
#
#                                       song_played         time_played
# id
# GOQMMKSQQH                               Hey Jude 2015-06-11 21:51:35
# HWKKBQKNWI                     We Can Work It Out 2015-06-06 16:49:19
# DKQSXVNJDH                   Back In the U.S.S.R. 2015-06-14 02:11:29
# HLHRIDQTUW                        P.s. I Love You 2015-06-08 12:26:10
# SUKJCSBCYW  Sgt. Pepper's Lonely Hearts Club Band 2015-06-28 14:57:00

# %%
song.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4000 entries, GOQMMKSQQH to LXJTCLWRUV
# Data columns (total 5 columns):
# user_id              4000 non-null int64
# user_state           4000 non-null object
# user_sign_up_date    4000 non-null datetime64[ns]
# song_played          4000 non-null object
# time_played          4000 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 187.5+ KB

# %% [markdown]
# ## Top 3 and Bottom 3 states in terms of number of users

# %%
user_numbers_by_states = song.groupby(song.user_state)['user_id'].apply(lambda x: len(np.unique(x))).sort_values(ascending = False)

# %%
print('Users are come from ',len(user_numbers_by_states),'States')
print('The TOP 3 States in terms of number of users are: ',user_numbers_by_states[:3].index.values)
print('The BOTTOM 3 States in terms of number of users are: ',user_numbers_by_states[:-4:-1].index.values)
user_numbers_by_states
# Out:
# Users are come from  41 States
# The TOP 3 States in terms of number of users are:  ['New York' 'California' 'Texas']
# The BOTTOM 3 States in terms of number of users are:  ['Arizona' 'New Mexico' 'Connecticut']
# user_state
# New York          23
# California        21
# Texas             15
# Pennsylvania       9
# Ohio               9
# Florida            7
# Illinois           7
# Georgia            6
# New Jersey         6
# North Carolina     6
# Massachusetts      6
# Michigan           5
# Wisconsin          5
# Maryland           5
# Louisiana          5
# Missouri           5
# Tennessee          5
# Indiana            4
# Minnesota          4
# Alabama            4
# West Virginia      3
# Oregon             3
# Colorado           3
# Kentucky           3
# South Carolina     3
# Mississippi        3
# Oklahoma           2
# Utah               2
# Virginia           2
# Washington         2
# Arkansas           2
# Alaska             2
# North Dakota       1
# Kansas             1
# Iowa               1
# Rhode Island       1
# Nebraska           1
# Idaho              1
# Connecticut        1
# New Mexico         1
# Arizona            1
# Name: user_id, dtype: int64

# %% [markdown]
# ## Top 3 and Bottom 3 states in terms of user engagement

# %% [markdown]
# I use 'average play per users' as a metric to measure user engagement behavior.

# %%
user_engagement_by_state = pd.DataFrame({'numbers_users':user_numbers_by_states,'numbers_songs':song.groupby('user_state').user_id.count()})
user_engagement_by_state['average_played_per_users'] = (user_engagement_by_state.numbers_songs/user_engagement_by_state.numbers_users)
user_engagement_by_state.average_played_per_users = user_engagement_by_state.average_played_per_users.astype('int')
user_engagement_by_state.sort_values(by = 'average_played_per_users',ascending =False,inplace= True)

# %%
print('The TOP 3 States in terms of engagement of users are: ',user_engagement_by_state[:3].index.values)
print('The BOTTOM 3 States in terms of engagement of users are: ',user_engagement_by_state[:-4:-1].index.values)
user_engagement_by_state
# Out:
# The TOP 3 States in terms of engagement of users are:  ['Nebraska' 'Alaska' 'Mississippi']
# The BOTTOM 3 States in terms of engagement of users are:  ['Virginia' 'Kansas' 'Minnesota']
#                 numbers_users  numbers_songs  average_played_per_users
# Nebraska                    1             36                        36
# Alaska                      2             58                        29
# Mississippi                 3             85                        28
# South Carolina              3             85                        28
# Rhode Island                1             27                        27
# Idaho                       1             26                        26
# North Dakota                1             26                        26
# Kentucky                    3             78                        26
# Alabama                     4            104                        26
# Florida                     7            180                        25
# Missouri                    5            127                        25
# North Carolina              6            154                        25
# Oklahoma                    2             49                        24
# Iowa                        1             23                        23
# Ohio                        9            209                        23
# Georgia                     6            135                        22
# Maryland                    5            112                        22
# Arizona                     1             22                        22
# Illinois                    7            149                        21
# Louisiana                   5            105                        21
# Washington                  2             41                        20
# Tennessee                   5            102                        20
# Oregon                      3             62                        20
# California                 21            425                        20
# New York                   23            469                        20
# New Jersey                  6            117                        19
# Pennsylvania                9            179                        19
# Utah                        2             38                        19
# Wisconsin                   5             95                        19
# Colorado                    3             54                        18
# New Mexico                  1             17                        17
# Arkansas                    2             34                        17
# Connecticut                 1             16                        16
# Michigan                    5             80                        16
# Massachusetts               6             91                        15
# Texas                      15            230                        15
# Indiana                     4             55                        13
# West Virginia               3             38                        12
# Minnesota                   4             42                        10
# Kansas                      1              8                         8
# Virginia                    2             17                         8

# %% [markdown]
# ## First signed-up users for each States

# %%
def first_users(df):
    signed_date = df.user_sign_up_date.min()
    users = df.loc[df.user_sign_up_date == signed_date,['user_id']]
    users = np.unique(users.user_id)
    return users[0]

# %% [markdown]
# def first_users(df):
#     signed_date = df.user_sign_up_date.idxmin()
#     return df.loc[signed_date,['user_id','user_sign_up_date']]

# %% [markdown]
# First signed-up users:

# %%
song.groupby('user_state').apply(first_users)
# Out:
# user_state
# Alabama             5
# Alaska            106
# Arizona           105
# Arkansas           78
# California         39
# Colorado          166
# Connecticut       127
# Florida            41
# Georgia            16
# Idaho             165
# Illinois           45
# Indiana           102
# Iowa              178
# Kansas            177
# Kentucky           34
# Louisiana          50
# Maryland           18
# Massachusetts      15
# Michigan           13
# Minnesota           8
# Mississippi        23
# Missouri           85
# Nebraska          134
# New Jersey          6
# New Mexico          4
# New York           10
# North Carolina      2
# North Dakota      135
# Ohio                3
# Oklahoma          119
# Oregon              1
# Pennsylvania       11
# Rhode Island      174
# South Carolina     64
# Tennessee          70
# Texas               7
# Utah               29
# Virginia          142
# Washington        125
# West Virginia      60
# Wisconsin          32
# dtype: int64

# %% [markdown]
# ## Recommendation Songs

# %%
print('There are ',song.song_played.unique().shape[0],'songs in company XYZ')
print('These are: ')
print(song.song_played.unique())
# Out:
# There are  100 songs in company XYZ
# These are:
# ['Hey Jude' 'We Can Work It Out' 'Back In the U.S.S.R.' 'P.s. I Love You'
#  "Sgt. Pepper's Lonely Hearts Club Band" 'Sgt. Pepper Inner Groove'
#  'Hello Goodbye' 'Cry For A Shadow' 'Revolution' 'Let It Be' 'I Feel Fine'
#  'The Fool On The Hill' 'Get Back' 'Come Together' 'She Loves You'
#  'While My Guitar Gently Weeps' 'Here Comes The Sun' 'A Day In The Life'
#  'Getting Better' "Baby You're A Rich Man" 'The Ballad Of John And Yoko'
#  'Lucy In The Sky With Diamonds' "Don't Let Me Down"
#  'Reprise / Day in the Life' "Maxwell's Silver Hammer"
#  'Across The Universe' 'Ob-la-di, Ob-la-da' 'Yesterday' 'Fixing A Hole'
#  'OH DARLING' 'Birthday' 'A Saturday Club Xmas/Crimble Medley'
#  'BALLAD OF JOHN AND YOKO' 'Got To Get You Into My Life' 'Wild Honey Pie'
#  'IN MY LIFE' 'Strawberry Fields Forever' 'Twist and Shout'
#  'I Saw Her Standing There' 'Helter Skelter' 'Something' 'Eleanor Rigby'
#  'Things We Said Today' 'Sgt. Pepper/with A Little Help From My Friends'
#  'You Never Give Me Your Money' 'YOUR MOTHER SHOULD KNOW'
#  'The Long And Winding Road' 'Sun King' "I've Got A Feeling"
#  'Eight Days A Week' 'Day Tripper' 'Roll Over Beethoven' 'I Am the Walrus'
#  'Lady Madonna' 'Good Day Sunshine' 'Blackbird' 'ROCK AND ROLL MUSIC'
#  "Can't Buy Me Love" 'Sgt. Pepper/a Day In The Life' 'Golden Slumbers'
#  'Magical Mystery Tour' "I Want You (She's So Heavy)"
#  'With a Little Help From My Friends' "She's Leaving Home"
#  'Yellow Submarine' 'THE CONTINUING STORY OF BUNG' 'BAD BOY'
#  "A Hard Day's Night" 'All My Loving' "You're Going To Lose That Girl"
#  "Everybody's Got Something To Hide Except Me And My Monk"
#  'Ticket to Ride' 'Drive My Car' 'The Word' "I'm A Loser" 'Help!'
#  'Dear Prudence' 'All You Need Is Love' 'Paperback Writer'
#  "I'll Follow The Sun" 'Rocky Raccoon' 'NOWHERE MAN'
#  "Sgt. Pepper's Lonely Hearts Club Band (Reprise)" "I've Just Seen A Face"
#  'Penny Lane' "SHE'S A WOMAN" 'And Your Bird Can Sing' 'Two Of Us'
#  'From Me To You' 'Please Please Me' 'GIRL' "IT WON'T BE LONG"
#  'Norwegian Wood' 'Love Me Do' 'I Want To Hold Your Hand' 'LITTLE CHILD'
#  'ANYTIME AT ALL' "I'm Down" 'Lovely Rita' "When I'm 64"]

# %% [markdown]
# We selected the users who played the selected song for the most frequently time, and then find their favrate songs that played most frequently and send it back to the users.

# %%
song_name = 'We Can Work It Out'
userid =song.loc[song['song_played']== song_name,:].groupby('user_id').time_played.count().sort_values(ascending = False).index[0]
rec_song = song.loc[(song.user_id == userid) & (song.song_played != song_name),:].groupby('song_played').time_played.count().sort_values(ascending = False).index[0]
rec_song
# Out:
# 'Twist and Shout'

# %% [markdown]
# Now, when user input a song's name, we can print a new song that are highest probability of being played based on this method.

# %% [markdown]
# #### Count song by users

# %%
song_count_by_users = song[['song_played','user_id']].groupby(['song_played','user_id']).user_id.count().unstack(level =-1,fill_value = 0)
song_count_by_users.head()
# Out:
# user_id                              1    2    3    4    5    6    7    8    \
# song_played
# A Day In The Life                      0    0    1    3    0    2    0    0
# A Hard Day's Night                     0    0    0    0    0    1    0    0
# A Saturday Club Xmas/Crimble Medley    0    0    0    0    0    0    0    0
# ANYTIME AT ALL                         0    0    0    0    0    0    0    0
# Across The Universe                    0    0    0    1    0    0    0    0
#
# user_id                              9    10   ...  191  192  193  194  195  \
# song_played                                    ...
# A Day In The Life                      0    0  ...    0    0    3    3    0
# A Hard Day's Night                     1    0  ...    0    0    0    0    1
# A Saturday Club Xmas/Crimble Medley    0    0  ...    0    0    0    0    0
# ANYTIME AT ALL                         0    0  ...    0    0    0    0    0
# Across The Universe                    0    0  ...    0    0    0    0    0
#
# user_id                              196  197  198  199  200
# song_played
# A Day In The Life                      2    0    0    2    0
# A Hard Day's Night                     0    0    0    0    0
# A Saturday Club Xmas/Crimble Medley    0    0    0    0    0
# ANYTIME AT ALL                         0    0    0    0    0
# Across The Universe                    0    0    0    0    0
#
# [5 rows x 196 columns]

# %%
from sklearn.preprocessing import normalize
song_count_by_users_norm = normalize(song_count_by_users, axis=1)
similar_song = song_count_by_users_norm.dot(song_count_by_users_norm.T)

# %%
similar_song = pd.DataFrame(similar_song, index= song_count_by_users.index, columns= song_count_by_users.index)
similar_song.head()
# Out:
# song_played                          A Day In The Life  A Hard Day's Night  \
# song_played
# A Day In The Life                             1.000000            0.235702
# A Hard Day's Night                            0.235702            1.000000
# A Saturday Club Xmas/Crimble Medley           0.074536            0.000000
# ANYTIME AT ALL                                0.119523            0.000000
# Across The Universe                           0.212132            0.100000
#
# song_played                          A Saturday Club Xmas/Crimble Medley  \
# song_played
# A Day In The Life                                               0.074536
# A Hard Day's Night                                              0.000000
# A Saturday Club Xmas/Crimble Medley                             1.000000
# ANYTIME AT ALL                                                  0.000000
# Across The Universe                                             0.000000
#
# song_played                          ANYTIME AT ALL  Across The Universe  \
# song_played
# A Day In The Life                          0.119523             0.212132
# A Hard Day's Night                         0.000000             0.100000
# A Saturday Club Xmas/Crimble Medley        0.000000             0.000000
# ANYTIME AT ALL                             1.000000             0.000000
# Across The Universe                        0.000000             1.000000
#
# song_played                          All My Loving  All You Need Is Love  \
# song_played
# A Day In The Life                         0.355023              0.329404
# A Hard Day's Night                        0.136931              0.111803
# A Saturday Club Xmas/Crimble Medley       0.000000              0.000000
# ANYTIME AT ALL                            0.154303              0.094491
# Across The Universe                       0.091287              0.000000
#
# song_played                          And Your Bird Can Sing   BAD BOY  \
# song_played
# A Day In The Life                                  0.152145  0.210819
# A Hard Day's Night                                 0.000000  0.000000
# A Saturday Club Xmas/Crimble Medley                0.000000  0.000000
# ANYTIME AT ALL                                     0.109109  0.000000
# Across The Universe                                0.000000  0.000000
#
# song_played                          BALLAD OF JOHN AND YOKO  ...  \
# song_played                                                   ...
# A Day In The Life                                   0.172133  ...
# A Hard Day's Night                                  0.091287  ...
# A Saturday Club Xmas/Crimble Medley                 0.000000  ...
# ANYTIME AT ALL                                      0.000000  ...
# Across The Universe                                 0.000000  ...
#
# song_played                          We Can Work It Out  When I'm 64  \
# song_played
# A Day In The Life                              0.464938     0.030429
# A Hard Day's Night                             0.259548     0.129099
# A Saturday Club Xmas/Crimble Medley            0.109435     0.000000
# ANYTIME AT ALL                                 0.116991     0.000000
# Across The Universe                            0.138426     0.000000
#
# song_played                          While My Guitar Gently Weeps  \
# song_played
# A Day In The Life                                        0.508964
# A Hard Day's Night                                       0.210099
# A Saturday Club Xmas/Crimble Medley                      0.000000
# ANYTIME AT ALL                                           0.138107
# Across The Universe                                      0.116722
#
# song_played                          Wild Honey Pie  \
# song_played
# A Day In The Life                          0.223607
# A Hard Day's Night                         0.000000
# A Saturday Club Xmas/Crimble Medley        0.166667
# ANYTIME AT ALL                             0.089087
# Across The Universe                        0.000000
#
# song_played                          With a Little Help From My Friends  \
# song_played
# A Day In The Life                                              0.359092
# A Hard Day's Night                                             0.000000
# A Saturday Club Xmas/Crimble Medley                            0.000000
# ANYTIME AT ALL                                                 0.183942
# Across The Universe                                            0.000000
#
# song_played                          YOUR MOTHER SHOULD KNOW  \
# song_played
# A Day In The Life                                   0.037268
# A Hard Day's Night                                  0.000000
# A Saturday Club Xmas/Crimble Medley                 0.000000
# ANYTIME AT ALL                                      0.000000
# Across The Universe                                 0.000000
#
# song_played                          Yellow Submarine  Yesterday  \
# song_played
# A Day In The Life                            0.318198   0.353220
# A Hard Day's Night                           0.050000   0.195468
# A Saturday Club Xmas/Crimble Medley          0.000000   0.000000
# ANYTIME AT ALL                               0.000000   0.146845
# Across The Universe                          0.000000   0.043437
#
# song_played                          You Never Give Me Your Money  \
# song_played
# A Day In The Life                                        0.087841
# A Hard Day's Night                                       0.074536
# A Saturday Club Xmas/Crimble Medley                      0.000000
# ANYTIME AT ALL                                           0.000000
# Across The Universe                                      0.000000
#
# song_played                          You're Going To Lose That Girl
# song_played
# A Day In The Life                                               0.0
# A Hard Day's Night                                              0.0
# A Saturday Club Xmas/Crimble Medley                             0.0
# ANYTIME AT ALL                                                  0.0
# Across The Universe                                             0.0
#
# [5 rows x 100 columns]

# %%
song_name = 'We Can Work It Out'
similar_song[song_name].sort_values(ascending = False)[1:2].index.values
# Out:
# array(['A Day In The Life'], dtype=object)

# %%
for i in list(song.song_played.unique()):
    s = similar_song[i].sort_values(ascending = False)[1:2].index.values
    print('{0:45s} | '.format(i),s)
# Out:
# Hey Jude                                      |  ['Come Together']
# We Can Work It Out                            |  ['A Day In The Life']
# Back In the U.S.S.R.                          |  ['Revolution']
# P.s. I Love You                               |  ['Golden Slumbers']
# Sgt. Pepper's Lonely Hearts Club Band         |  ['Lovely Rita']
# Sgt. Pepper Inner Groove                      |  ['Revolution']
# Hello Goodbye                                 |  ['Revolution']
# Cry For A Shadow                              |  ["I've Just Seen A Face"]
# Revolution                                    |  ['Come Together']
# Let It Be                                     |  ['Come Together']
# I Feel Fine                                   |  ['Here Comes The Sun']
# The Fool On The Hill                          |  ['I Feel Fine']
# Get Back                                      |  ['Revolution']
# Come Together                                 |  ['Revolution']
# She Loves You                                 |  ['Revolution']
# While My Guitar Gently Weeps                  |  ['Revolution']
# Here Comes The Sun                            |  ['Come Together']
# A Day In The Life                             |  ['Come Together']
# Getting Better                                |  ["Sgt. Pepper's Lonely Hearts Club Band"]
# Baby You're A Rich Man                        |  ['Sgt. Pepper/a Day In The Life']
# The Ballad Of John And Yoko                   |  ['Here Comes The Sun']
# Lucy In The Sky With Diamonds                 |  ['Get Back']
# Don't Let Me Down                             |  ['BALLAD OF JOHN AND YOKO']
# Reprise / Day in the Life                     |  ['Get Back']
# Maxwell's Silver Hammer                       |  ['With a Little Help From My Friends']
# Across The Universe                           |  ['Revolution']
# Ob-la-di, Ob-la-da                            |  ['Let It Be']
# Yesterday                                     |  ['Revolution']
# Fixing A Hole                                 |  ['IN MY LIFE']
# OH DARLING                                    |  ['Come Together']
# Birthday                                      |  ['Got To Get You Into My Life']
# A Saturday Club Xmas/Crimble Medley           |  ['GIRL']
# BALLAD OF JOHN AND YOKO                       |  ['Golden Slumbers']
# Got To Get You Into My Life                   |  ['Birthday']
# Wild Honey Pie                                |  ['Golden Slumbers']
# IN MY LIFE                                    |  ['Come Together']
# Strawberry Fields Forever                     |  ['Come Together']
# Twist and Shout                               |  ['Come Together']
# I Saw Her Standing There                      |  ['With a Little Help From My Friends']
# Helter Skelter                                |  ['Revolution']
# Something                                     |  ['Revolution']
# Eleanor Rigby                                 |  ['Get Back']
# Things We Said Today                          |  ['Come Together']
# Sgt. Pepper/with A Little Help From My Friends |  ['Come Together']
# You Never Give Me Your Money                  |  ['THE CONTINUING STORY OF BUNG']
# YOUR MOTHER SHOULD KNOW                       |  ['Lady Madonna']
# The Long And Winding Road                     |  ["I've Got A Feeling"]
# Sun King                                      |  ['She Loves You']
# I've Got A Feeling                            |  ['Come Together']
# Eight Days A Week                             |  ['Hey Jude']
# Day Tripper                                   |  ['Revolution']
# Roll Over Beethoven                           |  ['Strawberry Fields Forever']
# I Am the Walrus                               |  ['Revolution']
# Lady Madonna                                  |  ['Hello Goodbye']
# Good Day Sunshine                             |  ['With a Little Help From My Friends']
# Blackbird                                     |  ['Drive My Car']
# ROCK AND ROLL MUSIC                           |  ['Lucy In The Sky With Diamonds']
# Can't Buy Me Love                             |  ['Hello Goodbye']
# Sgt. Pepper/a Day In The Life                 |  ['Revolution']
# Golden Slumbers                               |  ['BALLAD OF JOHN AND YOKO']
# Magical Mystery Tour                          |  ['Revolution']
# I Want You (She's So Heavy)                   |  ["Everybody's Got Something To Hide Except Me And My Monk"]
# With a Little Help From My Friends            |  ['Come Together']
# She's Leaving Home                            |  ["I'm Down"]
# Yellow Submarine                              |  ['Get Back']
# THE CONTINUING STORY OF BUNG                  |  ['You Never Give Me Your Money']
# BAD BOY                                       |  ['Hey Jude']
# A Hard Day's Night                            |  ['Come Together']
# All My Loving                                 |  ['Let It Be']
# You're Going To Lose That Girl                |  ["I'll Follow The Sun"]
# Everybody's Got Something To Hide Except Me And My Monk |  ["I Want You (She's So Heavy)"]
# Ticket to Ride                                |  ['Back In the U.S.S.R.']
# Drive My Car                                  |  ['Hello Goodbye']
# The Word                                      |  ["I've Got A Feeling"]
# I'm A Loser                                   |  ['Helter Skelter']
# Help!                                         |  ['Let It Be']
# Dear Prudence                                 |  ['Got To Get You Into My Life']
# All You Need Is Love                          |  ['A Day In The Life']
# Paperback Writer                              |  ['Revolution']
# I'll Follow The Sun                           |  ["You're Going To Lose That Girl"]
# Rocky Raccoon                                 |  ['Revolution']
# NOWHERE MAN                                   |  ['GIRL']
# Sgt. Pepper's Lonely Hearts Club Band (Reprise) |  ['While My Guitar Gently Weeps']
# I've Just Seen A Face                         |  ['Cry For A Shadow']
# Penny Lane                                    |  ['We Can Work It Out']
# SHE'S A WOMAN                                 |  ['And Your Bird Can Sing']
# And Your Bird Can Sing                        |  ['All My Loving']
# Two Of Us                                     |  ['Something']
# From Me To You                                |  ['Strawberry Fields Forever']
# Please Please Me                              |  ['Lovely Rita']
# GIRL                                          |  ['A Saturday Club Xmas/Crimble Medley']
# IT WON'T BE LONG                              |  ['A Saturday Club Xmas/Crimble Medley']
# Norwegian Wood                                |  ["I'm Down"]
# Love Me Do                                    |  ['Fixing A Hole']
# I Want To Hold Your Hand                      |  ['Come Together']
# LITTLE CHILD                                  |  ['Across The Universe']
# ANYTIME AT ALL                                |  ["Can't Buy Me Love"]
# I'm Down                                      |  ['Norwegian Wood']
# Lovely Rita                                   |  ["Sgt. Pepper's Lonely Hearts Club Band"]
# When I'm 64                                   |  ["I've Just Seen A Face"]
